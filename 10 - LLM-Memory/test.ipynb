# %% [markdown]
# # LLM Memory {Short Term Memory}

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
import os

# %%
api_key = os.getenv('GROQ_API_KEY')
llm = ChatGroq(model="llama-3.1-8b-instant",api_key=api_key)

# %%
llm.invoke("My Hobbyes is Learn New Things ").content

# %%
llm.invoke("tell me about my hobbyes").content

# %%
# - Context Window
# - In Context Learning

messages= ["My Current Location is Nagpur, Please Response"]

# %%
output=llm.invoke(messages).content
output

# %%
messages.append(output)
messages

# %%
messages.append("What is My Current Location")
messages

# %%
output = llm.invoke(messages).content
output

# %%
llm.invoke("What is my Current Location")
# Out:
# AIMessage(content="I'm an AI and don't have the ability to access your device's location. However, I can guide you on how to find out your current location.\n\n1. **Using a Smartphone:**\n   - On an Android device, go to Settings > Location or Location services. This will show you your current location.\n   - On an iPhone, go to Settings > Location Services. This will allow you to see your current location.\n\n2. **Using a Computer:**\n   - If you're using a Google Chrome browser, you can click on the three dots at the top right corner and select 'Settings'. Scroll down to 'Advanced' and click on 'Location'. This will allow you to share your location with the browser.\n   - If you're using a desktop browser like Firefox or Safari, you can check your browser's settings to see if location services are enabled.\n\n3. **Using GPS:**\n   - You can also use a GPS device or a mapping app like Google Maps to find your current location.\n\nIf you're still unsure, please provide me with more c
# ...
