# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.1-8b-instant"
)

# %%
TASKS = []

# %%
from langchain.tools import tool

@tool
def add_task(task: str) -> str:
    """Task add in the TASKS"""
    TASKS.append({"task": task})
    return f"Task added: '{task}'"

@tool
def delete_task(task: str) -> str:
    """Delete the task"""
    if TASKS[]

# %%
llm_with_tools = llm.bind_tools([add_task])
llm_with_tools
# Out:
# RunnableBinding(bound=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000019DA886EB30>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000019DA886EC20>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'add_task', 'description': 'Task add in the TASKS', 'parameters': {'properties': {'task': {'type': 'string'}}, 'required': ['task'], 'type': 'object'}}}]}, config={}, config_factories=[])

# %%
user= "Add a task: lear English",

# %%
result = llm_with_tools.invoke(user)
result.tool_calls
# Out:
# [{'name': 'add_task',
#   'args': {'task': 'lear English'},
#   'id': '6cr9hpjtd',
#   'type': 'tool_call'}]

# %%
if hasattr(result, 'tool_calls'):
    for call in result.tool_calls:
        tool_name = call["name"]
        tool_args = call["args"]

        if tool_name == "add_task":
            tool_output = add_task.invoke(tool_args)
            print("\n⚙️ Tool Executed Output:")
            print(tool_output)

print(TASKS)
# Out:
# ⚙️ Tool Executed Output:
# Task added: 'lear English'
# [{'task': 'Learn LangChain Tools'}, {'task': 'Learn LangChain Tools'}, {'task': 'lear English'}]
